# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", None)

# %%
inventory_df = pd.read_csv("../data/processed/inventory_classified.csv")

inventory_df.head()
# Out:
#    sku_id  avg_actual_demand  avg_predicted_demand  demand_std  current_stock  \
# 0      38          34.043478             34.133961    7.132127           1055
# 1      29          31.264214             31.293951    7.871904            494
# 2      24          23.277592             23.430942    5.488842            776
# 3      39          29.729097             30.079778    5.737273            438
# 4      12          37.518395             37.570501    6.278398            710
#
#    selling_price  supplier_id  lead_time_days  avg_lead_time  \
# 0    1831.211806            1            11.0           11.0
# 1    1702.419699            5             5.0            5.0
# 2    2119.237224            2            10.0           10.0
# 3    1638.972642            7             5.0            5.0
# 4    1206.858395            8             7.0            7.0
#
#    lead_time_variability  safety_stock  reorder_point inventory_status  \
# 0                    4.0           308            727          Optimal
# 1                    2.0           128            304        Overstock
# 2                    2.0           322            593          Optimal
# 3                    4.0           173            341          Optimal
# 4                    4.0           352            641          Optimal
#
#    annual_consumptino_value  annual_consumption_value  cumulative_value  \
# 0              2.281488e+07              2.281488e+07      2.281488e+07
# 1              1.944554e+07              1.944554e+07      4.226041e+07
# 2              1.812434e+07              1.812434e+07      6.038475e+07
# 3              1.799448e+07              1.799448e+07      7.837923e+07
# 4              1.654993e+07              1.654993e+07      9.492916e+07
#
#    cumulative_percentage ABC_Class        cv XYZ_Class ABC_XYZ
# 0               6.107329         A  0.209501         X      AX
# 1              11.312717         A  0.251786         Y      AY
# 2              16.164434         A  0.235799         X      AX
# 3              20.981387         A  0.192985         X      AX
# 4              25.411648         A  0.167342         X      AX

# %%
inventory_df["calculated_safety_stock"] = (
    1.65 *
    inventory_df["demand_std"] *
    np.sqrt(inventory_df["lead_time_days"])
)

inventory_df[
    [
        "safety_stock",
        "calculated_safety_stock"
    ]
].head()
# Out:
#    safety_stock  calculated_safety_stock
# 0           308                39.030070
# 1           128                29.043485
# 2           322                28.639448
# 3           173                21.167737
# 4           352                27.408283

# %% [markdown]
# REorder point

# %%
inventory_df['calculated_reorder_point'] = (
    inventory_df['avg_predicted_demand']*
    inventory_df['lead_time_days']+
    inventory_df['calculated_safety_stock']
)

# %% [markdown]
# EOQ

# %%
ordering_cost = 500
holding_cost_rate =0.20

# %%
inventory_df['holding_cost'] =(
    inventory_df['selling_price']*
    holding_cost_rate
)

# %%
inventory_df["annual_demand"] = (

    inventory_df["avg_predicted_demand"]

    *

    365

)

# %%
inventory_df['EOQ'] = np.sqrt(
    (2*inventory_df['annual_demand']*
    ordering_cost)/ inventory_df['holding_cost']
)

# %% [markdown]
# Days of Inventory

# %%
inventory_df["days_of_inventory"] = (

    inventory_df["current_stock"]

    /

    inventory_df["avg_predicted_demand"]

)

# %% [markdown]
# Inventory Gap

# %%
inventory_df["inventory_gap"] = (

    inventory_df["current_stock"]

    -

    inventory_df["calculated_reorder_point"]

)
